# %% [markdown]
# # March 1:
# ---

# %% [markdown]
# ## OSCAR paper for Data Science: Reviews corrections
# After discussing with Silvio the first adaptions made to the paper, we have listed other important issues to take care of:
#
# **Comparison Table of the tools**
# * Investigate the 'Unknown' values and try figure out and write the corresponding values;
# * Remove the 'System Requirements' field, since it was the same value for all 'Web browser';
# * Deepen the analysis in some of the tools and write a more detailed description for the corresponding fields.
#
# **The paper**
# * Talk about the configuration process and the limits of OSCAR in the 'Conclusions' sections. In addition, give OSCAR a license;
# * Export the data of the Charts and make them citable through FigShare;
# * The paper title should not be changed, since 'Enabling text search ...' does not address only the Free-text search option;
# * Other minor changes.
#
# The above comments have been adjusted and I have updated the responses made to each Reviewer comment. Here you can see all the responses:
#
#
# <html><head><br><div style="box-sizing: border-box; font-size: 14px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);"><span style="box-sizing: border-box; font-size: 24px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255); color: rgb(0, 0, 0); font-family: &quot;Helvetica Neue&quot;, Helvetica, Arial, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;">Review 1</span></div><div style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255); padding: 0px; font-size: 14.9592px;"><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); font-size: 14.9592px; color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;">Doesn't really A/B test against the other text search or query-building engines described in Related Work.</span></div><div style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255); padding: 0px; font-size: 14.9592px;"><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; font-size: 14.9592px; color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">The usability of our tool is something we have treated in our previous publication through a dedicated user testing session. Although after evaluating the other </span><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; font-size: 14.9592px; color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">notes received from the</span><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; font-size: 14.9592px; color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;"> reviewers we decided to write </span><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; font-size: 14.9592px; color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">a dedicated subsection in “Related works" to compare OSCAR with the other searching and query-building tools presented, based on a set of relevant features/aspects.</span></div><div style="box-sizing: border-box; font-size: 14px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);"><span style="box-sizing: border-box; font-size: 14px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); color: rgb(0, 0, 0); font-family: &quot;Helvetica Neue&quot;, Helvetica, Arial, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;">Textual Errors</span></div><div style="box-sizing: border-box; font-size: 14px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);"><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;">"by means of appropriate facets and values" -- "facets and parameters”?    </span><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><div style="box-sizing: border-box; font-size: 14px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);"><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;">"OpenCitations Corpus (OCC) [8] and COCI (the OpenCitations Index of Crossref open DOI-to-DOI citations)" -- first is title (abbreviation), second is abbreviation (title); i think abbreviation (title) for both works better than the other way around.    </span><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><div style="box-sizing: border-box; font-size: 14px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);"><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;">"so as to search on these datasets" -- maybe "to enable search on these datasets”?    </span><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><div style="box-sizing: border-box; font-size: 14px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);"><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;">"Specify conversion rules are employed to" -- propose "User can specify conversion rules, which are employed to"…  </span><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><div style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);"><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px;"><span style="font-size: 9px; font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;">Should check whether the publication rules demand en-uk vs. en-us, c.f. "customisation".</span><span style="font-size: 14px; color: rgb(255, 38, 0); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;">    </span></span><span style="font-size: 9px; box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><div style="box-sizing: border-box; font-size: 14px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);"><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;">"customises OSCAR to work to a specific SPARQL-endpoint" -- s/to work to a/to work over a/    </span><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><div style="box-sizing: border-box; font-size: 14px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);"><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;">"so as to keep or excluding specific values" -- s/excluding/exclude/    </span><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><div style="box-sizing: border-box; font-size: 14px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);"><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;">"while OSCAR provide" -- s/provide/provides/    </span><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><div style="box-sizing: border-box; font-size: 14px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);"><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;">"query within in the text search box" -- s/in the/the/    </span><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><div style="box-sizing: border-box; font-size: 14px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);"><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;">"if a user choose to run" -- s/choose/chooses/    </span><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><div style="box-sizing: border-box; font-size: 14px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);"><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(0, 0, 0); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;">"other additional operations are executed" -- probably better with s/other //    </span><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><div style="box-sizing: border-box; font-size: 14px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);"><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;">"then OSCAR can be configured" -- can drop the "then"    </span><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><div style="box-sizing: border-box; font-size: 14px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);"><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;">"particular field (a key), all the fields" -- s/, all/. All/ # new sentence    </span><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><div style="box-sizing: border-box; font-size: 14px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);"><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;">"has more than one authors, the several rows will be returned" -- propose "has multiple authors, multiple rows will be returned”    </span><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><div style="box-sizing: border-box; font-size: 14px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);"><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;">"allows us to group all these authors" -- propose "groups all of these authors"    </span><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><div style="box-sizing: border-box; font-size: 14px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);"><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;">"bibliographic resource, since this IRI" -- s/,//    </span><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><div style="box-sizing: border-box; font-size: 14px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);"><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;">"specified category in order to build" -- I think there should be a ',' after "category"    </span><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><div style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);"><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251);"><span style="background-color: rgb(251, 251, 251); font-size: 9px; font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;">"constructs, and then moved" -- propose "constructs, which are then moved”</span></span><span style="font-size: 14px; box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(255, 38, 0); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;"> </span><span style="font-size: 9px; box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><div style="box-sizing: border-box; font-size: 14px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);"><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;">"pre-processing functions (key heuristics)" -- does that mean they are specified in the conf in the attribute name "heuristics”? </span><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">YES</span></div><div style="box-sizing: border-box; font-size: 14px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);"><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;">"each chosen searching strategy" -- s/searching/search/    </span><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><div style="box-sizing: border-box; font-size: 14px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);"><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;">"consulted previous articles which talks about" -- s/talks about/talk about/, or maybe just "discuss"    </span><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><div style="box-sizing: border-box; font-size: 14px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);"><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;">"For instance in Figure 5 the advanced query built asks to retrieve all the articles" -- propose "For instance, in Figure 5 the</span></div><div style="box-sizing: border-box; font-size: 14px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);"><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;">advanced query interface constructs a query retrieve all of the articles"    </span><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><div style="box-sizing: border-box; font-size: 14px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);"><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;">"input box dedicated for the free-text " -- s/dedicated for the free-text/dedicated to free-text/    </span><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><div style="box-sizing: border-box; font-size: 14px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);"><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;">"The query written in the interface asks to retrieve all the articles" -- propose "The constructed query retrieves all the articles"    </span><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><div style="box-sizing: border-box; font-size: 14px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);"><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;">"These data refers to the" -- s/refers/refer/    </span><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><div style="box-sizing: border-box; font-size: 14px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);"><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;">"Instead, in the second part" -- s/Instead //?    </span><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><div style="box-sizing: border-box; font-size: 14px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);"><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;">"beyond the purpose of this work" -- s/work/paper/ (or document)?    </span><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><div style="box-sizing: border-box; font-size: 14px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);"><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;">"listed in the results table" -- s/$/(OCC-browse, COCI-browse)/ # to clarify the legent in Figure 7.    </span><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><div style="box-sizing: border-box; font-size: 14px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);"><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;">"Beside this" -- s/Beside/Besides/    </span><span style="box-sizing: border-box; font-size: 9px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><div style="box-sizing: border-box; font-size: 14px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);"><span style="box-sizing: border-box; font-size: 24px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px;"><br/></span></div><div style="box-sizing: border-box; font-size: 14px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);"><span style="box-sizing: border-box; font-size: 24px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; color: rgb(0, 0, 0); font-family: &quot;Helvetica Neue&quot;, Helvetica, Arial, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;">Review 2</span></div><div style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255); padding: 0px; font-size: 14.9592px;"><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); font-size: 14.9592px; color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;">The title only focuses on one aspect of the tool (text search) and could be modified to indicate that OSCAR has more general capabilities.</span></div><div style="box-sizing: border-box; orphans: 2; text-align: start; text-indent: 0px; widows: 2; background-color: rgb(255, 255, 255); padding: 0px;"><span style="font-size: 14px; letter-spacing: normal; text-transform: none; white-space: normal; word-spacing: 0px; -webkit-text-stroke-width: 0px; box-sizing: border-box; orphans: 2; text-indent: 0px; widows: 2; color: rgb(4, 51, 255); font-family: &quot;Helvetica Neue&quot;, Helvetica, Arial, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">OSCAR inputs are only textual in both types of searches: free-text search, and the advanced search. By writing “</span><span style="font-size: 13px; letter-spacing: normal; text-transform: none; white-space: normal; word-spacing: 0px; -webkit-text-stroke-width: 0px;"><span style="font-size: 13px; color: rgb(4, 51, 255); font-weight: bold;">Enabling text search</span></span><span style="caret-color: rgb(4, 51, 255);"><span style="color: rgb(4, 51, 255); font-family: &quot;Helvetica Neue&quot;, Helvetica, Arial, sans-serif; font-weight: bold;">”</span></span><span style="color: rgb(4, 51, 255); font-family: &quot;Helvetica Neue&quot;, Helvetica, Arial, sans-serif; font-weight: bold;"> we mean both searching options handled. </span></div><div style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255); padding: 0px; font-size: 14.9592px;"><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); font-size: 14.9592px; color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;">Full citation of the previous version is not appropriate for an abstract and should be removed.</span></div><div style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255); padding: 0px; font-size: 14.9592px;"><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255); font-size: 14.9592px; color: rgb(4, 51, 255); font-family: &quot;Helvetica Neue&quot;, Helvetica, Arial, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">The hyperlinks in the abstract have been removed, although they are cited later in the paper.</span></div><div style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255); padding: 0px; font-size: 14.9592px;"><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); font-size: 14.9592px; color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;">The five-point list of enhancements which is included in the Introduction should be moved to section 3 or the summary and conclusions.</span></div><div style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255); padding: 0px; font-size: 14.9592px;"><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; font-size: 14.9592px;"><span style="font-size: 14.9592px; color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">This work is an extension of a previous paper (Special Issue), therefore we wanted to list the additions made compared to the previous publication. We think that these facts should be mentioned in the begging of it.</span></span></div><div style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255); padding: 0px; font-size: 14.9592px;"><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); font-size: 14.9592px; color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;">ELDA (the Epimorphics Linked Data API) is an additional general purpose tool for masking a SPARQL endpoint, with a simple configuration method, which should perhaps be added to the review of related work.</span></div><div style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255); padding: 0px; font-size: 14.9592px;"><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255); font-size: 14.9592px; color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">We added and talked about ELDA in the ‘Related works’ section. In addition, ELDA was also included in the comparison table.</span></div><div style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255); padding: 0px; font-size: 14.9592px;"><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); font-size: 14.9592px; color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;">There is no real comparison of the capabilities of OSCAR with related tools - just a relatively cursory overview. A tabulation of the features of each compared with OSCAR would be helpful.</span></div><div style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255); padding: 0px; font-size: 14.9592px;"><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255); font-size: 14.9592px; color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">We made a dedicated subsection in “Related works" to compare OSCAR with the other searching and query-building tools presented, based on a set of relevant features/aspects.</span></div><div style="box-sizing: border-box; font-size: 14px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);"><span style="box-sizing: border-box; font-size: 14px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); color: rgb(0, 0, 0); font-family: &quot;Helvetica Neue&quot;, Helvetica, Arial, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;">Section 3 contains some rather detailed technical description of the tool.</span></div><div style="box-sizing: border-box; font-size: 14px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);"><span style="box-sizing: border-box; font-size: 14px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); color: rgb(0, 0, 0); font-family: &quot;Helvetica Neue&quot;, Helvetica, Arial, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;">Some of sections 3.2 and 3.3 is possibly too much for a journal or conference paper, and perhaps should be left as references to technical documentation.</span></div><div style="box-sizing: border-box; font-size: 14px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);"><span style="box-sizing: border-box; font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;"><font color="#0433ff">We think this is essential to let users understand some technical aspects of OSCAR, and understand how to correctly customise, and re-use it for there own purposes.</font></span></div><div style="box-sizing: border-box; font-size: 14px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);"><span style="box-sizing: border-box; font-size: 24px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px;"><br/></span></div><div style="box-sizing: border-box; font-size: 14px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);"><span style="box-sizing: border-box; font-size: 24px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; color: rgb(0, 0, 0); font-family: &quot;Helvetica Neue&quot;, Helvetica, Arial, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;">Review 3</span></div><div style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255); padding: 0px; font-size: 14.9592px;"><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); font-size: 14.9592px; color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;">Papers describing tools hardly fit with the usual review criteria (e.g., the novelty and validation of contribution) but I think some extra effort can be made to clear the contribution of OSCAR from the scientific point of view. </span><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); font-size: 14.9592px; color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;">For example, </span><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); font-size: 14.9592px; color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;">in relation with the novelty of contribution, what does OSCAR provide that the others do not? A deeper comparison between OSCAR and the tools mentioned in the related work would substantiate the novelty of contribution from the scientific perspective.</span></div><div style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255); padding: 0px; font-size: 14.9592px;"><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; font-size: 14.9592px; color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">We made a dedicated subsection in “Related works" to compare OSCAR with the other searching and query-building tools presented, based on a set of relevant features/aspects.</span></div><div style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255); padding: 0px; font-size: 14.9592px;"><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); font-size: 14.9592px; color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;">In relation to OSCAR usefulness, I have no problem believing it is useful. However, showing the Usage statistics retrieved from the OpenCitations website logs is a very weak proof of its usefulness. It does not distinguish between the usefulness of the content served by OpenCitations and the actual usefulness of OSCAR. Of course, it is better than nothing, but actual user satisfaction using OSCAR should be more systematically investigated.</span></div><div style="box-sizing: border-box; orphans: 2; text-align: start; text-indent: 0px; widows: 2; background-color: rgb(255, 255, 255); padding: 0px;"><span style="font-size: 14.9592px; letter-spacing: normal; text-transform: none; white-space: normal; word-spacing: 0px; -webkit-text-stroke-width: 0px; box-sizing: border-box; orphans: 2; text-indent: 0px; widows: 2;"><span style="font-family: &quot;Helvetica Neue&quot;, Helvetica, Arial, sans-serif; font-size: 14.9592px; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold; color: rgb(4, 51, 255);">Fair point, in fact the u</span></span><span style="font-weight: bold; color: rgb(4, 51, 255);">sage statistics reported demonstrate the OSCAR </span><span style="caret-color: rgb(255, 38, 0); font-weight: bold; color: rgb(4, 51, 255);">‘</span><span style="font-weight: bold; color: rgb(4, 51, 255);"> usage’ and not its ‘Usefulness’.</span><span style="font-weight: bold; color: rgb(255, 38, 0);">  </span></div><div style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255); padding: 0px; font-size: 14.9592px;"><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); font-size: 14.9592px; color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;">Selected Keywords (i.e., OpenOffice, ODT to RASH) do not relate to the content of the paper.</span></div><div style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255); padding: 0px; font-size: 14.9592px;"><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; font-size: 14.9592px; color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">We changed the set of keywords to: OSCAR -- OpenCitations -- OCC -- COCI -- SPARQL -- Free-text search -- Scholarly data -- Advanced search</span></div><div style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255); padding: 0px; font-size: 14.9592px;"><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); font-size: 14.9592px; color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;">Please state explicitly that OSCAR can be applied beyond scholarly data portals, as it is configurable on any SPARQL endpoint and RDF schema.</span></div><div style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255); padding: 0px; font-size: 14.9592px;"><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255); font-size: 14.9592px; color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">“</span><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255); font-size: 14.9592px; color: rgb(4, 51, 255); font-family: &quot;Helvetica Neue&quot;, Helvetica, Arial, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">Since our focus is on scholarly data we will still query the other SPARQL endpoints taken as example, to retrieve data on such domain, although we would like to strengthen the fact that OSCAR is fully customizable and applicable for SPARQL endpoints for RDF triplestores containing other type of data. </span><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255); font-size: 14.9592px; color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">“ in the Introduction section (at the end of it).</span></div><div style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255); padding: 0px; font-size: 14.9592px;"><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); font-size: 14.9592px; color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;">In the related works, I would consider citing YASGUI as an example of an interface for semantic web literate. Laurens Rietveld, Rinke Hoekstra, The YASGUI family of SPARQL clients. Semantic Web 8(3): 373-383 (2017)</span></div><div style="box-sizing: border-box; font-size: 14px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);"><span style="box-sizing: border-box; font-size: 14px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255); color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">Done, we have also added YASQUI to the comparison table.</span></div><div style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255); padding: 0px; font-size: 14.9592px;"><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); font-size: 14.9592px; color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;">In the caption of figure 1, "workshop [4].The", there is a missing space.</span></div><div style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255); padding: 0px; font-size: 14.9592px;"><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255); font-size: 14.9592px; color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">Done</span></div><div style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255); padding: 0px; font-size: 14.9592px;"><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); font-size: 14.9592px; color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;">Configuration examples might be not easy to grasp, I think a reference to the configuration instructions and the inclusion of some comments in the configuration file might help.</span></div><div style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255); padding: 0px; font-size: 14.9592px;"><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); font-size: 14.9592px; color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;">I suggest adding a discussion of the limitations and applicability of OSCAR. For example, in a separate section. In such a section, the authors might want to answer the following questions: When configuring OSCAR is less handy than writing a custom user interface? Under what kind of licence OSCAR is made available? is there any assistance in case one has any difficulties when configuring/using OSCAR? etc</span><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); font-size: 14.9592px; color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;">.</span></div><div style="box-sizing: border-box; orphans: 2; text-align: start; text-indent: 0px; widows: 2; background-color: rgb(255, 255, 255); padding: 0px;"><div><span style="font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-weight: bold; color: rgb(4, 51, 255);">The current License of OSCAR is MIT, we have inserted this additional information in the paper along with some final notes addressing users that wish to use and integrate OSCAR with their services.</span><span style="font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-weight: bold; color: rgb(255, 38, 0);">   </span></div></div><div style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255); padding: 0px; font-size: 14.9592px;"><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); font-size: 14.9592px; color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;">One thing I've noticed playing with the results from </span><a href="http://opencitations.net/search?text=machine+learning" style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); font-size: 14.9592px; outline: none; color: rgb(0, 132, 146); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; text-decoration: underline;-evernote-highlight:true;">http://opencitations.net/search?text=machine+learning</a><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); font-size: 14.9592px; color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;"> : if one sorts the results by the number of citations, and limits the number of results visualized, he gets the first ten results in the result set, not the first ten most-cited papers. This is extremely counterintuitive! I suggest to fix it in the next release of OSCAR.</span></div><div style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255); padding: 0px; font-size: 14.9592px;"><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; font-size: 14.9592px; color: rgb(4, 51, 255); font-family: &quot;Helvetica Neue&quot;, Helvetica, Arial, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">Thanks for the notice. We might take this as an issue to discuss in the future releases.</span></div><div style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255); padding: 0px; font-size: 14.9592px;"><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); font-size: 14.9592px; color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;">The Data science journal requires that all used and produced data are openly available in established data repositories, as mandated by FAIR and the data availability guidelines (</span><a href="https://journals.plos.org/plosone/s/data-availability" style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); font-size: 14.9592px; outline: none; color: rgb(0, 132, 146); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; text-decoration: underline;-evernote-highlight:true;">https://journals.plos.org/plosone/s/data-availability</a><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); font-size: 14.9592px; color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;">). As far as I understand the guidelines have not followed for the statistics regarding the accesses to OSCAR used in section 5. Please fix it or make clear how you have met the availability guidelines.</span></div><div style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255); padding: 0px; font-size: 14.9592px;"><div><span style="-en-paragraph:true;"><span style="font-size: 14.9592px; font-weight: bold; color: rgb(4, 51, 255);">The data of the charts have been uploaded on Figshare. We have mentioned and cite such source on the paper also.</span><span style="font-size: 14.9592px; font-weight: bold;"> </span></span></div><div><br/></div></div><div style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255); padding: 0px; font-size: 14.9592px;"><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; font-size: 24px; color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;">Meta-Review </span></div><div style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255); padding: 0px; font-size: 14.9592px;"><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: pre-wrap; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); font-size: 14.6667px; color: rgb(0, 0, 0); font-family: Arial; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;">In particular, please address the concerns by all reviewers about including a more in depth comparison with other tools and describe what are OSCAR’s distinctive advantages. For example, consider including a table comparing OSCAR’s functionality against the functionality provided by other tools. Do include in the comparison the new tools suggested by reviewers. Please, also address the distinction between the tool and its data content and provide ways of evaluating both. In addition, please make available all the material required to evaluate the tool and content (e.g. the usage statistics).</span></div><div style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255); padding: 0px; font-size: 14.9592px;"><div><span style="box-sizing: border-box; font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">We made a dedicated subsection in “Related works" to compare OSCAR with the other searching and query-building tools presented, based on a set of relevant features/aspects.</span></div></div><div style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255); padding: 0px; font-size: 14.9592px;"><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: pre-wrap; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); font-size: 11pt; color: rgb(0, 0, 0); font-family: Arial; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;">As regards the availability of associated material, while OSCAR development is open and you provide the GitHub repository (</span><a href="https://github.com/opencitations/oscar" style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: pre-wrap; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); font-size: 11pt; outline: none; color: rgb(17, 85, 204); font-family: Arial; font-variant-caps: normal; font-variant-ligatures: normal; text-decoration: underline;-evernote-highlight:true;">https://github.com/opencitations/oscar</a><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: pre-wrap; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); font-size: 11pt; color: rgb(0, 0, 0); font-family: Arial; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;">),  there are currently no releases in that repository. I recommend you create a release and use the GitHub/Zenodo association to obtain a DOI and make the code citable (see</span><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); font-size: 14.9592px; color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;"> </span><a href="https://guides.github.com/activities/citable-code/" style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: pre-wrap; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); font-size: 11pt; outline: none; color: rgb(17, 85, 204); font-family: Arial; font-variant-caps: normal; font-variant-ligatures: normal; text-decoration: underline;-evernote-highlight:true;">https://guides.github.com/activities/citable-code/</a><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: pre-wrap; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); font-size: 11pt; color: rgb(0, 0, 0); font-family: Arial; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;">). Thus, please include a citation to your software using the Zenodo DOI.</span></div><div style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255); padding: 0px; font-size: 14.9592px;"><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: pre-wrap; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); font-size: 11pt; color: rgb(0, 0, 0); font-family: Arial; font-variant-caps: normal; font-variant-ligatures: normal; line-height: 1.38;-evernote-highlight:true;">Finally, take into account all the textual changes indicated by reviewers and proofread the paper again (e.g. avoid the repetition of SAVE-SD workshop URL in the introduction).</span></div><div style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255); padding: 0px; font-size: 14.9592px;"><span style="box-sizing: border-box; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: pre-wrap; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; font-size: 11pt; color: rgb(4, 51, 255); font-family: Arial; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold; line-height: 1.38;">Done. We have one link only to SAVE-SD right now (in the Introduction).</span></div><div><br/></div><div><span style="font-style: normal; font-weight: normal;" /></div></body></html>

# %% [markdown]
# ## Attending the seminar of Liam Wyatt
# The title of the work presented was *"Everything You Always Wanted to Know About Wikimedia But Were Afraid to Ask"*.
# Liam talk has adressed the Europeana project (https://www.europeana.eu/portal/it), along with the WikiMedia foundation main projects. He mostly highlighted Wikidata and Wikipedia and the differences between them with some practical examples.
# I have taken some notes about it on Evernote also at https://www.evernote.com/l/AOi_5jk-Ol9DWpRFKnU-0Jw6uiwZVtWQddw

# %% [markdown]
# ## Ph.D. Abstract
# I think I can consider the first section of it *Background and Purpose* close to an acceptable final version.
# I have also finished writing the 'Design/methodology/approach' section, although I feel I can add other important details regarding the working strategies I will adopt.
# I am currently writing the Findings sections. I believe this section should contain the objectivies I __hope__ achiving through my research, I will reconsider the questions raised in the 'Background and Purpose' section and try answer them here.
#
# I am writing it using Evernote (https://www.evernote.com/l/AOjJJ82P3etAtpA-c_9CA-k7qZynCkf1SgM).
# Here I post a preview of it:

# %% [markdown]
# <br><br>
# <html><head><meta http-equiv="Content-Type" content="text/html; charset=UTF-8"/><meta name="exporter-version" content="Evernote Mac 7.8 (457454)"/><meta name="altitude" content="45.95061111450195"/><meta name="author" content="ivanhb.ita@gmail.com"/><meta name="created" content="2019-01-10 11:10:02 +0000"/><meta name="latitude" content="44.49677059573768"/><meta name="longitude" content="11.35356707407617"/><meta name="source" content="desktop.mac"/><meta name="updated" content="2019-03-01 16:36:22 +0000"/><meta name="reminder-order" content="2019-01-10 11:10:02 +0000"/><meta name="reminder-time" content="2019-01-17 07:00:00 +0000"/><meta name="reminder-done-time" content="2019-01-27 13:58:27 +0000"/><title>Ph.D. Abstract</title></head><body><div style="margin-top: 1em; margin-bottom: 1em;"/><h1 style="text-align: center;"><span style="font-size: 18pt; white-space: pre-wrap;"><span style="font-size: 18pt; color: rgb(0, 0, 0); font-family: Georgia; font-variant-caps: normal; font-variant-ligatures: normal; line-height: 1.38;">The application of Semantic Publishing technologies in the Science of Science research domain for Humanities and Social Science fields</span></span></h1><div><br/></div><h3 style="text-align: center;"><span style="font-size: 13.999999999999998pt; white-space: pre-wrap;"><span style="font-size: 13.999999999999998pt; color: rgb(67, 67, 67); font-family: Georgia; font-variant-caps: normal; font-variant-ligatures: normal; line-height: 1.38;">Background and Purpose</span></span></h3><div style="margin-top: 1em; margin-bottom: 1em;"><span style="font-size: 12pt;white-space: pre-wrap;-en-paragraph:true;"><span style="font-size: 12pt; color: rgb(0, 0, 0); font-family: Georgia; font-variant-caps: normal; font-variant-ligatures: normal; line-height: 1.656;">SoS (Science of Science) [1] purpose is to q</span></span><span style="font-size: 12pt; white-space: pre-wrap; color: rgb(0, 0, 0); font-family: Georgia; font-variant-caps: normal; font-variant-ligatures: normal; line-height: 1.656;-en-paragraph:true;">uantify and predict scientific researches and their resulting outcomes</span><span style="font-size: 12pt;white-space: pre-wrap;-en-paragraph:true;"><span style="font-size: 12pt; color: rgb(0, 0, 0); font-family: Georgia; font-variant-caps: normal; font-variant-ligatures: normal; line-height: 1.656;">. The main purpose of my work is the application of this field of study into Social Sciences and Humanities domain, which have gained less attentions in literature compared to the scientific fields [2]. </span></span><span style="font-size: 16px; font-family: Georgia; line-height: 1.656;">Mainly, through this work I would like to focus on two major aspects concerning the scholarly publications in Humanities disciplines: </span><span style="font-size: 16px; font-family: Georgia; line-height: 1.656;">Citations and Indicator/Metrics used to evaluate researches. When dealing with citations, I would like to focus and answer on these two questions:</span></div><ul><li><div><span style="font-size: 16px; font-family: Georgia;">What are the common leading patterns used by authors when citing and creating the bibliographic reference ?</span></div></li><li><div><span style="font-size: 16px; font-family: Georgia;">What are the reasons to cite other works, also known as the</span><span style="font-size: 16px; font-family: Georgia;"> citation function </span><span style="font-size: 16px; font-family: Georgia;">[3]</span><span style="font-size: 16px; font-family: Georgia;"> ?</span></div></li></ul><div><span style="font-size: 16px;"><br/></span></div><div><span style="font-size: 16px; font-family: Georgia;">On the other hand, when talking about level indicators and </span><span style="font-size: 16px; font-family: Georgia;">research evaluation,</span><span style="font-size: 16px; font-family: Georgia;"> I would like to answer the question:</span></div><ul><li><div><span style="font-size: 16px; font-family: Georgia;">What are the metrics used comparing to the scientific fields, their effectiveness, and if there are other metrics we might consider for an alternative researches evaluation for Humanities domain ? </span></div></li></ul><h3 style="text-align: center;"><span style="font-size: 13.999999999999998pt; white-space: pre-wrap;"><span style="font-size: 13.999999999999998pt; color: rgb(67, 67, 67); font-family: Georgia; font-variant-caps: normal; font-variant-ligatures: normal; line-height: 1.38;">Design/methodology/approach</span></span></h3><div style="margin-top: 1em; margin-bottom: 1em;"><span style="font-size: 12pt; white-space: pre-wrap; color: rgb(0, 0, 0); font-family: Georgia; font-variant-caps: normal; font-variant-ligatures: normal; line-height: 1.656;-en-paragraph:true;">The main approach is based on using the Semantic Web technologies [4], such that the</span><span style="font-family: Georgia; line-height: 1.656;-en-paragraph:true;" /><span style="font-size: 12pt; white-space: pre-wrap; color: rgb(51, 51, 51); font-family: Georgia; font-variant-caps: normal; font-variant-ligatures: normal; line-height: 1.656;-en-paragraph:true;">data are represent in the form of a globally linked database</span><span style="font-family: Georgia; line-height: 1.656;-en-paragraph:true;" /><span style="font-size: 12pt; white-space: pre-wrap; color: rgb(0, 0, 0); font-family: Georgia; font-variant-caps: normal; font-variant-ligatures: normal; line-height: 1.656;-en-paragraph:true;">with</span><span style="font-family: Georgia; line-height: 1.656;-en-paragraph:true;" /><span style="font-size: 12pt; white-space: pre-wrap; color: rgb(51, 51, 51); font-family: Georgia; font-variant-caps: normal; font-variant-ligatures: normal; line-height: 1.656;-en-paragraph:true;">the attribution of a semantic content.</span><span style="font-family: Georgia; line-height: 1.656;-en-paragraph:true;" /><span style="font-size: 12pt; white-space: pre-wrap; color: rgb(0, 0, 0); font-family: Georgia; font-variant-caps: normal; font-variant-ligatures: normal; line-height: 1.656;-en-paragraph:true;">Applying the Semantic Web technologies in the scholarly publishing domain, is also known as "Semantic Publishing” [5][6]. This approach has already been adapted and still used in many projects (e.g. OpenCitations [7]), gaining positive impacts mostly in its application to scientific fields.</span></div><div style="text-align: center; margin-top: 1em; margin-bottom: 1em;"><span style="caret-color: rgb(67, 67, 67); font-size: 18.66666603088379px; white-space: pre-wrap;"><span style="font-size: 18.66666603088379px; color: rgb(67, 67, 67); font-family: Georgia; font-weight: bold;">Findings</span></span></div><div style="text-align: left; margin-top: 1em; margin-bottom: 1em;"><span style="font-size: 12pt; white-space: pre-wrap; color: rgb(0, 0, 0); font-family: Georgia; font-variant-caps: normal; font-variant-ligatures: normal; line-height: 1.656;-en-paragraph:true;">Citation analysis concerning the two </span><span style="font-size: 12pt; white-space: pre-wrap; color: rgb(0, 0, 0); font-family: Georgia; font-variant-caps: normal; font-variant-ligatures: normal; line-height: 1.656;-en-paragraph:true;">previous </span><span style="font-size: 12pt; white-space: pre-wrap; color: rgb(0, 0, 0); font-family: Georgia; font-variant-caps: normal; font-variant-ligatures: normal; line-height: 1.656;-en-paragraph:true;">questions might let us:  (a) understand their usage and define common patterns, concerning different features, e.g. the context. (b) classify and identify reasons for citing based on relevant features.  On the other hand, when dealing with indicators, hopefully we will be able to understand better the current ones, and proposing alternative methodologies to handle the negativities of the current ones.</span></div><div style="text-align: left; margin-top: 1em; margin-bottom: 1em;"><span style="font-size: 12pt; white-space: pre-wrap; color: rgb(0, 0, 0); font-family: Georgia; font-variant-caps: normal; font-variant-ligatures: normal; line-height: 1.656;-en-paragraph:true;"><br/></span></div><div style="text-align: left; margin-top: 1em; margin-bottom: 1em;"><span style="font-size: 12pt; white-space: pre-wrap; color: rgb(0, 0, 0); font-family: Georgia; font-variant-caps: normal; font-variant-ligatures: normal; line-height: 1.656;-en-paragraph:true;"><br/></span></div><div style="margin-top: 1em; margin-bottom: 1em;"><span style="font-size: 24px; font-family: Georgia;">References</span></div><ol><li><div><span style="font-size: 14px; font-family: Georgia;">Fortunato, S., Bergstrom, C. T., Börner, K., Evans, J. A., Helbing, D., Milojević, S., ... &amp; Vespignani, A. (2018). Science of science. Science, 359(6379), eaao0185. DOI: </span><a href="https://doi.org/10.1126/science.aao0185" style="font-size: 14px; font-family: Georgia;">https://doi.org/10.1126/science.aao0185</a></div></li><li><div><span style="font-size: 14px; font-family: Georgia;">Martín-Martín, A., Orduna-Malea, E., Thelwall, M., &amp; López-Cózar, E. D. (2018). Google Scholar, Web of Science, and Scopus: A systematic comparison of citations in 252 subject categories. Journal of Informetrics, 12(4), 1160-1177. DOI: </span><a href="https://doi.org/10.1016/j.joi.2018.09.002%0A" style="font-size: 14px; font-family: Georgia;">https://doi.org/10.1016/j.joi.2018.09.002 </a></div></li><li><div><span style="font-size: 14px; font-family: Georgia;">Teufel, S., Siddharthan, A., &amp; Tidhar, D. (2006). An annotation scheme for citation function.</span></div></li><li><div><span style="font-family: Georgia;">Berners-Lee, T., &amp; Hendler, J. (2001). Publishing on the semantic web. Nature, 410(6832), 1023. DOI: </span><span style="font-family: Georgia;"><a href="https://doi.org/10.1038/35074206" style="font-family: Georgia;">https://doi.org/10.1038/35074206</a> </span></div></li><li><div><span style="font-size: 14px; font-family: Georgia;">Shotton, D. (2009). Semantic publishing: the coming revolution in scientific journal publishing. DOI: </span><a href="https://doi.org/10.1087/2009202%0A" style="font-size: 14px; font-family: Georgia;">https://doi.org/10.1087/2009202</a></div></li><li><div><span style="font-size: 14px; font-family: Georgia;">Shotton, D., Portwin, K., Klyne, G., &amp;amp; Miles, A. (2009). Adventures in semantic publishing: exemplar semantic enhancements of a research article. PLoS computational biology, 5(4), e1000361. DOI: </span><a href="https://doi.org/10.1371/journal.pcbi.1000361%0A" style="font-size: 14px; font-family: Georgia;">https://doi.org/10.1371/journal.pcbi.1000361</a></div></li><li><div><span style="font-family: Georgia;">Peroni, S., Dutton, A., Gray, T., &amp; Shotton, D. (2015). Setting our bibliographic references free: towards open citation data. Journal of Documentation, 71(2), 253-277. DOI: </span><span style="font-family: Georgia;"><a href="https://doi.org/10.1108/JD-12-2013-0166" style="font-family: Georgia;">https://doi.org/10.1108/JD-12-2013-0166</a> </span></div></li></ol><div style="margin-top: 1em; margin-bottom: 1em;"><div><br/></div><div><br/></div></div><div><br/></div><div style="margin-top: 1em; margin-bottom: 1em;"><br/></div><div style="margin-top: 1em; margin-bottom: 1em;"><span style="font-size: 24px;"></body></html>
