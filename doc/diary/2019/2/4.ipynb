# %% [markdown]
# # February 22:
# ---

# %% [markdown]
# ## Handling the reviewers notes for the DataScience paper
#
# Here I will list all the reviewers notes and my responses. The blue responses denotes adaptions that have been made, rather the red ones, are doubtful and need a further discussion with Silvio and David.
#
# <html><head><br><br><div><span style="font-size: 24px;">Review 1</span></div><div style="padding: 0px; font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; margin-top: 1em; margin-bottom: 1em;"><span style="font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;-en-paragraph:true;">Doesn't really A/B test against the other text search or query-building engines described in Related Work.
# </span></div><div style="padding: 0px; font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; margin-top: 1em; margin-bottom: 1em;"><span style="font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);-en-paragraph:true;"><span style="font-size: 14.9592px; font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; font-style: italic; font-weight: bold; color: rgb(4, 51, 255);">We made a dedicated subsection in “Related works" to compare OSCAR with the other searching and query-building tools presented, based on a set of relevant features/aspects.</span></span></div><div><span style="background-color: rgb(255, 250, 165);-evernote-highlight:true;">Textual Errors</span></div><div><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251);"><span style="background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; font-size: 9px;">"by means of appropriate facets and values" -- "facets and parameters”?    </span></span><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); font-size: 9px; color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><hr/><div><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251);"><span style="background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; font-size: 9px;">"OpenCitations Corpus (OCC) [8] and COCI (the OpenCitations Index of Crossref open DOI-to-DOI citations)" -- first is title (abbreviation), second is abbreviation (title); i think abbreviation (title) for both works better than the other way around.    </span></span><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); font-size: 9px;"><span style="background-color: rgb(251, 251, 251); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-size: 9px; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold; color: rgb(4, 51, 255);">DONE</span></span></div><hr/><div><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251);"><span style="background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; font-size: 9px;">"so as to search on these datasets" -- maybe "to enable search on these datasets”?    </span></span><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); font-size: 9px; color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><hr/><div><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251);"><span style="background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; font-size: 9px;">"Specify conversion rules are employed to" -- propose "User can specify conversion rules, which are employed to"…  </span></span><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); font-size: 9px; color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><hr/><div><span style="orphans: 2; widows: 2; background-color: rgb(255, 255, 255);"><span style="background-color: rgb(255, 255, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; color: rgb(255, 38, 0); font-size: 14px;">Should check whether the publication rules demand en-uk vs. en-us, c.f. "customisation".</span></span></div><hr/><div><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251);"><span style="background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; font-size: 9px;">"customises OSCAR to work to a specific SPARQL-endpoint" -- s/to work to a/to work over a/    </span></span><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); font-size: 9px; color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><hr/><div><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251);"><span style="background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; font-size: 9px;">"so as to keep or excluding specific values" -- s/excluding/exclude/    </span></span><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); font-size: 9px; color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><hr/><div><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251);"><span style="background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; font-size: 9px;">"while OSCAR provide" -- s/provide/provides/    </span></span><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); font-size: 9px; color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><hr/><div><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251);"><span style="background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; font-size: 9px;">"query within in the text search box" -- s/in the/the/    </span></span><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); font-size: 9px; color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><hr/><div><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251);"><span style="background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; font-size: 9px;">"if a user choose to run" -- s/choose/chooses/    </span></span><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); font-size: 9px; color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><hr/><div><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251);"><span style="background-color: rgb(251, 251, 251); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; font-size: 9px;">"other additional operations are executed" -- probably better with s/other //    </span></span><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); font-size: 9px; color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><hr/><div><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251);"><span style="background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; font-size: 9px;">"then OSCAR can be configured" -- can drop the "then"    </span></span><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); font-size: 9px; color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><hr/><div><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251);"><span style="background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; font-size: 9px;">"particular field (a key), all the fields" -- s/, all/. All/ # new sentence    </span></span><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); font-size: 9px; color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><hr/><div><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251);"><span style="background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; font-size: 9px;">"has more than one authors, the several rows will be returned" -- propose "has multiple authors, multiple rows will be returned”    </span></span><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); font-size: 9px; color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><hr/><div><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251);"><span style="background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; font-size: 9px;">"allows us to group all these authors" -- propose "groups all of these authors"    </span></span><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); font-size: 9px; color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><hr/><div><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251);"><span style="background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; font-size: 9px;">"bibliographic resource, since this IRI" -- s/,//    </span></span><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); font-size: 9px; color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><hr/><div><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251);"><span style="background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; font-size: 9px;">"specified category in order to build" -- I think there should be a ',' after "category"    </span></span><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); font-size: 9px; color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><hr/><div><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251);"><span style="background-color: rgb(251, 251, 251); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; color: rgb(255, 38, 0); font-size: 14px;">"constructs, and then moved" -- propose "constructs, which are then moved"</span></span></div><hr/><div><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251);"><span style="background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; font-size: 9px;">"pre-processing functions (key heuristics)" -- does that mean they are specified in the conf in the attribute name "heuristics”? </span></span><span style="font-size: 9px; orphans: 2; widows: 2; background-color: rgb(251, 251, 251);"><span style="background-color: rgb(251, 251, 251); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-size: 9px; font-style: italic; font-weight: bold; color: rgb(4, 51, 255);">YES</span></span></div><hr/><div><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251);"><span style="background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; font-size: 9px;">"each chosen searching strategy" -- s/searching/search/    </span></span><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); font-size: 9px; color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><hr/><div><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251);"><span style="background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; font-size: 9px;">"consulted previous articles which talks about" -- s/talks about/talk about/, or maybe just "discuss"    </span></span><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); font-size: 9px; color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><hr/><div><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251);"><span style="background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; font-size: 9px;">"For instance in Figure 5 the advanced query built asks to retrieve all the articles" -- propose "For instance, in Figure 5 the </span></span></div><div><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251);"><span style="background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; font-size: 9px;">advanced query interface constructs a query retrieve all of the articles"    </span></span><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); font-size: 9px; color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><hr/><div><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251);"><span style="background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; font-size: 9px;">"input box dedicated for the free-text " -- s/dedicated for the free-text/dedicated to free-text/    </span></span><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); font-size: 9px; color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><hr/><div><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251);"><span style="background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; font-size: 9px;">"The query written in the interface asks to retrieve all the articles" -- propose "The constructed query retrieves all the articles"    </span></span><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); font-size: 9px; color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><hr/><div><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251);"><span style="background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; font-size: 9px;">"These data refers to the" -- s/refers/refer/    </span></span><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); font-size: 9px; color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><hr/><div><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251);"><span style="background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; font-size: 9px;">"Instead, in the second part" -- s/Instead //?    </span></span><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); font-size: 9px; color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><hr/><div><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251);"><span style="background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; font-size: 9px;">"beyond the purpose of this work" -- s/work/paper/ (or document)?    </span></span><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); font-size: 9px; color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><hr/><div><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251);"><span style="background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; font-size: 9px;">"listed in the results table" -- s/$/(OCC-browse, COCI-browse)/ # to clarify the legent in Figure 7.    </span></span><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); font-size: 9px; color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><hr/><div><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251);"><span style="background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; font-size: 9px;">"Beside this" -- s/Beside/Besides/    </span></span><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); font-size: 9px; color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;">DONE</span></div><div><span style="font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251);"><br/></span></div><div><span style="font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251);"><br/></span></div><div><span style="font-size: 24px;">Review 2</span></div><div style="padding: 0px; font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; margin-top: 1em; margin-bottom: 1em;"><span style="font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;-en-paragraph:true;">The title only focuses on one aspect of the tool (text search) and could be modified to indicate that OSCAR has more general capabilities.
# </span></div><div style="padding: 0px; orphans: 2; text-align: start; text-indent: 0px; widows: 2; margin-top: 1em; margin-bottom: 1em;"><span style="font-weight: bold; color: rgb(4, 51, 255);">OSCAR does indeed do also advanced/complex queries. We change it to a more general title: “Searching SPARQL-endpoints through OSCAR"</span></div><div style="padding: 0px; font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; margin-top: 1em; margin-bottom: 1em;"><span style="font-size: 14.9592px; background-color: rgb(255, 250, 165); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif;-evernote-highlight:true;">Full citation of the previous version is not appropriate for an abstract and should be removed.</span></div><div style="padding: 0px; font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; margin-top: 1em; margin-bottom: 1em;"><span style="font-size: 14.9592px; font-weight: bold; color: rgb(4, 51, 255);">The hyperlinks in the abstract have been removed, although they are cited later in the paper.</span></div><div style="padding: 0px; font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; margin-top: 1em; margin-bottom: 1em;"><span style="font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;-en-paragraph:true;">The five-point list of enhancements which is included in the Introduction should be moved to section 3 or the summary and conclusions.
# </span></div><div style="padding: 0px; font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; margin-top: 1em; margin-bottom: 1em;"><span style="font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);-en-paragraph:true;"><span style="font-size: 14.9592px; font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; color: rgb(255, 38, 0); font-weight: bold;">Not sure about this one.</span></span></div><div style="padding: 0px; font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; margin-top: 1em; margin-bottom: 1em;"><span style="font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;-en-paragraph:true;">ELDA (the Epimorphics Linked Data API) is an additional general purpose tool for masking a SPARQL endpoint, with a simple configuration method, which should perhaps be added to the review of related work.
# </span></div><div style="padding: 0px; font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; margin-top: 1em; margin-bottom: 1em;"><span style="font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px;-en-paragraph:true;"><span style="font-size: 14.9592px; font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; color: rgb(4, 51, 255); font-weight: bold;">We added and talked about ELDA in the ‘Related works’ section. In addition, ELDA was also included in the comparison table.</span></span></div><div style="padding: 0px; font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; margin-top: 1em; margin-bottom: 1em;"><span style="font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;-en-paragraph:true;">There is no real comparison of the capabilities of OSCAR with related tools - just a relatively cursory overview. A tabulation of the features of each compared with OSCAR would be helpful.
# </span></div><div style="padding: 0px; font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; margin-top: 1em; margin-bottom: 1em;"><span style="font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;-en-paragraph:true;">We made a dedicated subsection in “Related works" to compare OSCAR with the other searching and query-building tools presented, based on a set of relevant features/aspects.</span></div><p style="padding: 0px; color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-size: 14.9592px; font-variant-ligatures: normal; font-variant-caps: normal; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px;"/><div><span style="background-color: rgb(255, 250, 165);-evernote-highlight:true;">Section 3 contains some rather detailed technical description of the tool.</span></div><div style="margin-top: 1em; margin-bottom: 1em;"><span style="background-color: rgb(255, 250, 165);-evernote-highlight:true;-en-paragraph:true;">Some of sections 3.2 and 3.3 is possibly too much for a journal or conference paper, and perhaps should be left as references to technical documentation.
# </span></div><div style="margin-top: 1em; margin-bottom: 1em;"><span style="font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; color: rgb(255, 38, 0); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;-en-paragraph:true;">We think this is essential to let users understand some technical aspects of OSCAR, and understand how to correctly customise, and re-use it for there own purposes.</span></div><div style="margin-top: 1em; margin-bottom: 1em;"><span style="background-color: rgb(255, 250, 165);-evernote-highlight:true;-en-paragraph:true;"><br/></span></div><div style="margin-top: 1em; margin-bottom: 1em;"><span style="font-size: 24px;">Review 3</span></div><div style="padding: 0px; font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; margin-top: 1em; margin-bottom: 1em;"><span style="font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;-en-paragraph:true;">Papers describing tools hardly fit with the usual review criteria (e.g., the novelty and validation of contribution) but I think some extra effort can be made to clear the contribution of OSCAR from the scientific point of view. </span><span style="background-color: rgb(255, 250, 165);-evernote-highlight:true;"><span style="font-size: 14.9592px; background-color: rgb(255, 250, 165); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;">For example, </span><span style="font-size: 14.9592px; background-color: rgb(255, 250, 165); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;">in relation with the novelty of contribution, what does OSCAR provide that the others do not? A deeper comparison between OSCAR and the tools mentioned in the related work would substantiate the novelty of contribution from the scientific perspective.</span></span></div><div style="padding: 0px; font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; margin-top: 1em; margin-bottom: 1em;"><span style="font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;-en-paragraph:true;">We made a dedicated subsection in “Related works" to compare OSCAR with the other searching and query-building tools presented, based on a set of relevant features/aspects.</span></div><div style="padding: 0px; font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; margin-top: 1em; margin-bottom: 1em;"><span style="font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;">In relation to OSCAR usefulness, I have no problem believing it is useful. However, showing the Usage statistics retrieved from the OpenCitations website logs is a very weak proof of its usefulness. It does not distinguish between the usefulness of the content served by OpenCitations and the actual usefulness of OSCAR. Of course, it is better than nothing, but actual user satisfaction using OSCAR should be more systematically investigated.</span></div><div style="padding: 0px; font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; margin-top: 1em; margin-bottom: 1em;"><span style="font-size: 14.9592px; font-weight: bold; color: rgb(255, 38, 0);">Of course a dedicated user testing session could be very beneficial in this case. Although, we think this might need a dedicated special analysis and it goes far from our paper goals.</span></div><div style="padding: 0px; font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; margin-top: 1em; margin-bottom: 1em;"><span style="font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;">Selected Keywords (i.e., OpenOffice, ODT to RASH) do not relate to the content of the paper.</span></div><div style="padding: 0px; font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; margin-top: 1em; margin-bottom: 1em;"><span style="font-size: 14.9592px; font-family: &quot;Trebuchet MS&quot;; color: rgb(4, 51, 255); font-weight: bold;">We changed the set of keywords to: OSCAR -- OpenCitations -- OCC -- COCI -- SPARQL -- Free-text search -- Scholarly data -- Advanced search</span></div><div style="padding: 0px; font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; margin-top: 1em; margin-bottom: 1em;"><span style="font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;-en-paragraph:true;">Please state explicitly that OSCAR can be applied beyond scholarly data portals, as it is configurable on any SPARQL endpoint and RDF schema.
# </span></div><div style="padding: 0px; font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; margin-top: 1em; margin-bottom: 1em;"><span style="font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; color: rgb(4, 51, 255); font-weight: bold; font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-en-paragraph:true;">“</span><span style="font-size: 14.9592px; color: rgb(4, 51, 255); font-weight: bold;-en-paragraph:true;">Since our focus is on scholarly data we will still query the other SPARQL endpoints taken as example, to retrieve data on such domain, although we would like to strengthen the fact that OSCAR is fully customizable and applicable for SPARQL endpoints for RDF triplestores containing other type of data.
# </span><span style="font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; color: rgb(4, 51, 255); font-weight: bold; font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-en-paragraph:true;">“ in the Introduction section (at the end of it).</span></div><div style="padding: 0px; font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; margin-top: 1em; margin-bottom: 1em;"><span style="font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;-en-paragraph:true;">In the related works, I would consider citing YASGUI as an example of an interface for semantic web literate. Laurens Rietveld, Rinke Hoekstra, The YASGUI family of SPARQL clients. Semantic Web 8(3): 373-383 (2017)
# </span></div><div style="orphans: 2; widows: 2; text-align: start;"><font face="Trebuchet MS, Helvetica Neue, Arial, Helvetica, sans-serif" size="3" color="#0433ff"><b>Done, we have also added YASQUI to the comparison table.</b></font></div><div style="padding: 0px; font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; margin-top: 1em; margin-bottom: 1em;"><span style="font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;-en-paragraph:true;">In the caption of figure 1, "workshop [4].The", there is a missing space.
# </span></div><div style="padding: 0px; font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; margin-top: 1em; margin-bottom: 1em;"><span style="font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px;-en-paragraph:true;"><span style="font-size: 14.9592px; font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;"><font color="#0433ff">Done</font></span></span></div><div style="padding: 0px; font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; margin-top: 1em; margin-bottom: 1em;"><span style="font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;">Configuration examples might be not easy to grasp, I think a reference to the configuration instructions and the inclusion of some comments in the configuration file might help.</span></div><div style="padding: 0px; font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; margin-top: 1em; margin-bottom: 1em;"><span style="font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;">I suggest adding a discussion of the limitations and applicability of OSCAR. For example, in a separate section. In such a section, the authors might want to answer the following questions: When configuring OSCAR is less handy than writing a custom user interface? Under what kind of licence OSCAR is made available? is there any assistance in case one has any difficulties when configuring/using OSCAR? etc</span><span style="font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(251, 251, 251); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;">.</span></div><div style="padding: 0px; font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; margin-top: 1em; margin-bottom: 1em;"><span style="font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; color: rgb(255, 38, 0); font-weight: bold;-en-paragraph:true;">Not sure about it.</span><br/></div><div style="padding: 0px; font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; margin-top: 1em; margin-bottom: 1em;"><span style="background-color: rgb(255, 250, 165);-evernote-highlight:true;"><span style="font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;">One thing I've noticed playing with the results from </span><a href="http://opencitations.net/search?text=machine+learning" style="outline: none; font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); color: rgb(0, 132, 146); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;">http://opencitations.net/search?text=machine+learning</a><span style="font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;"> : if one sorts the results by the number of citations, and limits the number of results visualized, he gets the first ten results in the result set, not the first ten most-cited papers. This is extremely counterintuitive! I suggest to fix it in the next release of OSCAR.</span></span></div><div style="padding: 0px; font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; margin-top: 1em; margin-bottom: 1em;"><b><font color="#0433ff">Thanks for the notice. We might take this as an issue to discuss in the future releases.</font></b></div><div style="padding: 0px; font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; margin-top: 1em; margin-bottom: 1em;"><span style="background-color: rgb(255, 250, 165);-evernote-highlight:true;"><span style="font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;">The Data science journal requires that all used and produced data are openly available in established data repositories, as mandated by FAIR and the data availability guidelines (</span><a href="https://journals.plos.org/plosone/s/data-availability" style="outline: none; font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); color: rgb(0, 132, 146); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;">https://journals.plos.org/plosone/s/data-availability</a><span style="font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;">). As far as I understand the guidelines have not followed for the statistics regarding the accesses to OSCAR used in section 5. Please fix it or make clear how you have met the availability guidelines.</span></span></div><div style="padding: 0px; font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; margin-top: 1em; margin-bottom: 1em;"><span style="font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal; color: rgb(255, 38, 0); font-weight: bold;-en-paragraph:true;">Not sure about it. We need to make public the log files !?</span><br/></div><div style="padding: 0px; font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; margin-top: 1em; margin-bottom: 1em;"><span style="font-size: 24px; color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;">Meta-Review </span></div><div style="padding: 0px; font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; margin-top: 1em; margin-bottom: 1em;"><span style="font-size: 14.6667px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: pre-wrap; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); color: rgb(0, 0, 0); font-family: Arial; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;">In particular, please address the concerns by all reviewers about including a more in depth comparison with other tools and describe what are OSCAR’s distinctive advantages. For example, consider including a table comparing OSCAR’s functionality against the functionality provided by other tools. Do include in the comparison the new tools suggested by reviewers. Please, also address the distinction between the tool and its data content and provide ways of evaluating both. In addition, please make available all the material required to evaluate the tool and content (e.g. the usage statistics).</span></div><div style="padding: 0px; font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; margin-top: 1em; margin-bottom: 1em;"><span style="font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; color: rgb(4, 51, 255); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-style: italic; font-variant-caps: normal; font-variant-ligatures: normal; font-weight: bold;-en-paragraph:true;">We made a dedicated subsection in “Related works" to compare OSCAR with the other searching and query-building tools presented, based on a set of relevant features/aspects.</span><br/></div><div style="padding: 0px; font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; margin-top: 1em; margin-bottom: 1em;"><span style="background-color: rgb(255, 250, 165); font-size: 14.9592px; color: rgb(46, 46, 46); font-family: &quot;Trebuchet MS&quot;, &quot;Helvetica Neue&quot;, Arial, Helvetica, sans-serif; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;"><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; font-size: 11pt; white-space: pre-wrap; background-color: rgb(255, 250, 165); color: rgb(0, 0, 0); font-family: Arial; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;">As regards the availability of associated material, while OSCAR development is open and you provide the GitHub repository (</span><a href="https://github.com/opencitations/oscar" style="outline: none; font-size: 11pt; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: pre-wrap; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); font-family: Arial; font-variant-caps: normal; font-variant-ligatures: normal; color: rgb(17, 85, 204); text-decoration: underline;-evernote-highlight:true;">https://github.com/opencitations/oscar</a><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; font-size: 11pt; white-space: pre-wrap; background-color: rgb(255, 250, 165); color: rgb(0, 0, 0); font-family: Arial; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;">),  there are currently no releases in that repository. I recommend you create a release and use the GitHub/Zenodo association to obtain a DOI and make the code citable (see</span> <a href="https://guides.github.com/activities/citable-code/" style="outline: none; font-size: 11pt; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: pre-wrap; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); font-family: Arial; font-variant-caps: normal; font-variant-ligatures: normal; color: rgb(17, 85, 204); text-decoration: underline;-evernote-highlight:true;">https://guides.github.com/activities/citable-code/</a><span style="letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; font-size: 11pt; white-space: pre-wrap; background-color: rgb(255, 250, 165); color: rgb(0, 0, 0); font-family: Arial; font-variant-caps: normal; font-variant-ligatures: normal;-evernote-highlight:true;">). Thus, please include a citation to your software using the Zenodo DOI.</span></span></div><div style="padding: 0px; text-align: start; font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; margin-top: 1em; margin-bottom: 1em;"><span style="font-size: 11pt; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: pre-wrap; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 250, 165); color: rgb(0, 0, 0); font-family: Arial; font-variant-caps: normal; font-variant-ligatures: normal; line-height: 1.38;-evernote-highlight:true;-en-paragraph:true;">Finally, take into account all the textual changes indicated by reviewers and proofread the paper again (e.g. avoid the repetition of SAVE-SD workshop URL in the introduction).</span></div><div style="padding: 0px; text-align: start; font-size: 14.9592px; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; margin-top: 1em; margin-bottom: 1em;"><span style="font-size: 11pt; letter-spacing: normal; orphans: 2; text-indent: 0px; text-transform: none; white-space: pre-wrap; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; font-family: Arial; font-variant-caps: normal; font-variant-ligatures: normal; line-height: 1.38;-en-paragraph:true;"><font color="#0433ff"><b><i>Done. We have one link only to SAVE-SD right now (in the Introduction).</i></b></font></span></div></body></html>

# %% [markdown]
# ## The Tools comparison table to include in the DataScience paper
# Currently the tools analyzed are: __OSCAR, Scholia, BioCarian, NITELIGHT, ELDA, ViziQuer, Visual SPARQL Builder (VSB), WDQS, YASGUI__
# <br>
# The set of features taken in consideration are:
# __Searching options,
# Dataset,
# Pre processing,
# Post processing,
# Filtering options,
# View and edit the SPARQL query,
# Statistics and performances on the executed Query,
# Layout,
# Presentation,
# Export data,
# System requirements,
# Customisability,
# Programming language__
# <br>
# You can view the whole table in .ODS format <a href="https://ivanhb.github.io/phd/paper/OSCAR(Special-issue)-DataScience/article/v2/comparison_table.ods">HERE</a>. Some of the cells still need to be filled, the red values are those in need of a further analysis.

# %% [markdown]
# ## Phd abstract
# I have dedicated this week on an overall examination of the literature materials regarding Bibliometrics and Scientometric on Humanities domain. I have classified the papers and documents read in two categories, using Zotero:
# 1) Background on Scientometric for Humanities and its limits.
# 2) The methods adopted regarding this field.
# I will sum up the things I gained into the abstract in the next days.
